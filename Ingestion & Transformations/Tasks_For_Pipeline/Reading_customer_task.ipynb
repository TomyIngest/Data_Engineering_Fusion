# %%
project_catalog = dbutils.widgets.get("catalog")
project_schema = dbutils.widgets.get("schema")

df = (spark.read.format("csv")
        .options(header=True,
                 inferSchema = True)
        .load('/Volumes/data_fusion/source_data/v03_pipeline/customers.csv')
        )

# %%
# %sql
USE CATALOG ${catalog};
CREATE SCHEMA IF NOT EXISTS ${schema};

# %%
df.write.mode('overwrite').saveAsTable(f'{project_catalog}.{project_schema}.bronze_customers')

df.limit(5).display()
