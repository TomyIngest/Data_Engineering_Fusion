# %%
# %sql
CREATE VOLUME IF NOT EXISTS data_fusion.source_data.v03_Pipeline

# %%
dbutils.fs.cp('/Volumes/db_academy_retail/v01/source_files','/Volumes/data_fusion/source_data/v03_pipeline', recurse=True)

# %%
# %sql
--  Deleting schema bronze_tables_pipeline
DROP SCHEMA IF EXISTS data_fusion.bronze_tables_pipeline CASCADE
